# %%
# %run params.ipynb

# %%
if 'graph' in PARAMS:
    orig_G = PARAMS['graph']
else:
    import rule_factory
    orig_G = rule_factory.get_rules('example')['graph']

# %%
import networkx as nx

nodes = list(orig_G)

for node in nodes:
    G = orig_G.copy()    
    G.remove_edges_from([(node, target) for target in list(G[node])])
    PARAMS['graph'] = G
    PARAMS['label'] = "del_" + node
    # %run "01. structural analysis.ipynb"
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /work/Vitaljok/Actin/01. structural analysis.ipynb in <module>()
#      28
#      29 if PARAMS['save_file']:
# ---> 30     plt.savefig(build_filename(PARAMS, 'dependency_matrix', 'png'), bbox_inches='tight');
#
# /opt/conda/lib/python3.5/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     686 def savefig(*args, **kwargs):
#     687     fig = gcf()
# --> 688     res = fig.savefig(*args, **kwargs)
#     689     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     690     return res
#
# /opt/conda/lib/python3.5/site-packages/matplotlib/figure.py in savefig(self, *args, **kwargs)
#    1563             self.set_frameon(frameon)
#    1564
# -> 1565         self.canvas.print_figure(*args, **kwargs)
#    1566
#    1567         if frameon:
#
# ...
