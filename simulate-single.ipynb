# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import matplotlib
import matplotlib.pylab as pl
import boolean2 as bl

# %%
import rules.v02_fixing_Arp2_3 as rul
import utils
# import importlib

# %%
# importlib.reload(rul)

model = bl.Model(rul.build_rules()["rules"], mode='sync')
model.initialize(missing=bl.util.randbool)
model.iterate(steps=30)

pl.figure(figsize=(10,8))
utils.plot_model(model.data);
# utils.plot_model({key: model.data[key] for key in ['Arp2_3', 'WAVE', 'WASP', 'Cortactin', 'Profilin', 'Coronin', 'Thymosin']})

# %%
print(utils.voting_rule(['A', 'B'], ['X', 'Y'], strongInhibition=True).replace(" or ", " or\n"))
# Out:
# not A and B and not X and not Y or
# A and not B and not X and not Y or
# A and B and not X and not Y or
# A and B and not X and Y or
# A and B and X and not Y
